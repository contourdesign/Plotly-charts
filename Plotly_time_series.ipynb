# %%
import pandas as pd
import numpy as np
import plotly
from plotly import __version__
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
# import chart studio
import chart_studio.plotly as py

# %%
df = pd.read_csv('tesla.csv')

df.head()
# Out:
#          date   close         volume    open    high       low
# 0       11:34  270.49      4,787,699  264.50  273.88  262.2400
# 1  2018/10/15  259.59   6189026.0000  259.06  263.28  254.5367
# 2  2018/10/12  258.78   7189257.0000  261.00  261.99  252.0100
# 3  2018/10/11  252.23   8128184.0000  257.53  262.25  249.0300
# 4  2018/10/10  256.88  12781560.0000  264.61  265.51  247.7700

# %%
# remove first row
df = df.iloc[1: , :]
#df = df.sort_values(df.date, ascending=True)
df.head(20)
# Out:
#           date   close         volume    open      high       low
# 1   2018/10/15  259.59   6189026.0000  259.06  263.2800  254.5367
# 2   2018/10/12  258.78   7189257.0000  261.00  261.9900  252.0100
# 3   2018/10/11  252.23   8128184.0000  257.53  262.2500  249.0300
# 4   2018/10/10  256.88  12781560.0000  264.61  265.5100  247.7700
# 5   2018/10/09  262.80  12037780.0000  255.25  266.7700  253.3000
# 6   2018/10/08  250.56  13371180.0000  264.52  267.7599  249.0000
# 7   2018/10/05  261.95  17900710.0000  274.65  274.8800  260.0000
# 8   2018/10/04  281.83   9638885.0000  293.95  294.0000  277.6700
# 9   2018/10/03  294.80   7982272.0000  303.33  304.6000  291.5700
# 10  2018/10/02  301.02  11699690.0000  313.95  316.8400  299.1500
# 11  2018/10/01  310.70  21714210.0000  305.77  311.4400  301.0500
# 12  2018/09/28  264.77  33597290.0000  270.26  278.0000  260.5550
# 13  2018/09/27  307.52   7337760.0000  312.90  314.9600  306.9100
# ...

# %%
data = [go.Scatter(
    x = df.date,
    y = df.close
)]

iplot(data)
# Out:
# <div>                            <div id="ec239abd-446e-4c91-bad4-3a43f6c2b335" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec239abd-446e-4c91-bad4-3a43f6c2b335")) {                    Plotly.newPlot(                        "ec239abd-446e-4c91-bad4-3a43f6c2b335",                        [{"type":"scatter","x":["2018/10/15","2018/10/12","2018/10/11","2018/10/10","2018/10/09","2018/10/08","2018/10/05","2018/10/04","2018/10/03","2018/10/02","2018/10/01","2018/09/28","2018/09/27","2018/09/26","2018/09/25","2018/09/24","2018/09/21","2018/09/20","2018/09/19","2018/09/18","2018/09/17","2018/09/14","2018/09/13","2018/09/12","2018/09/11","2018/09/10","2018/09/07","2018/09/06","2018/09/05","2018/09/04","2018/08/31","2018/08/30","2018/08/29","2018/08/28","2
# ...

# %%
#convert date to correct format
df["date"] = df["date"].apply(pd.to_datetime)

# %%
df.dtypes
# Out:
# date      datetime64[ns]
# close            float64
# volume            object
# open             float64
# high             float64
# low              float64
# dtype: object

# %%
# # api_key input to put online
import chart_studio.plotly as py


chart_studio.tools.set_credentials_file(username='contourdesign', api_key='BF0s2H59iO1JUkjmx0y0')


trace1 = go.Scatter(
    x=df.date,
    y=df.high,
    name='tesla_high',
    line = dict(color='#17becf'),
    opacity = 0.8
)

trace2 = go.Scatter(
    x=df.date,
    y=df.low,
    name='tesla_low',
    line = dict(color='#7f7f7f'),
    opacity = 0.8
)

data = [trace1, trace2]

layout = dict(
    title='Tesla stock high vs. low'
)

#fig = dict(data=data, layout=layout
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='telsa-hi-lo')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\envs\PythonData\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# ...
